# %% [markdown]
# #   **Weather Data Analysis**

# %% [markdown]
# **Presented By:**

# %% [raw]
# 1- Thorat Yogesh
# 2- Tamboli Saniya

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv(r"D:/EXL capstone project/Weather Data.csv")

# %% [markdown]
# **r-->to remove the uni-code errors**

# %%
data
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9       86.0              4.0
# 1        1/1/2012 1:00    -1.8              -3.7       87.0              4.0
# 2        1/1/2012 2:00     NaN              -3.4       89.0              7.0
# 3        1/1/2012 3:00    -1.5              -3.2       88.0              6.0
# 4        1/1/2012 4:00    -1.5               NaN       88.0              7.0
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7       81.0             30.0
# 8780  12/31/2012 20:00     0.2              -2.4       83.0             24.0
# 8781  12/31/2012 21:00    -0.5              -1.5       93.0             28.0
# 8782  12/31/2012 22:00    -0.2              -1.8       89.0             28.0
# 8783  12/31/2012 23:00     0.0              -2.1       86.0             30.0
#
# ...

# %% [markdown]
# # **Analyze DataFrame**

# %%
data.head()                                  #it shows 1st 5 head Data of the dataframe
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9       86.0              4.0
# 1  1/1/2012 1:00    -1.8              -3.7       87.0              4.0
# 2  1/1/2012 2:00     NaN              -3.4       89.0              7.0
# 3  1/1/2012 3:00    -1.5              -3.2       88.0              6.0
# 4  1/1/2012 4:00    -1.5               NaN       88.0              7.0
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
data.shape    #it shows the number of rows n columns in Dataset
# Out:
# (8784, 8)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=8784, step=1)

# %%
data.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%           float64
# Wind Speed_km/h     float64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %%
data['Weather'].unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', nan, 'Snow Showers', 'Snow',
#        'Clear', 'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %%
data.nunique()
# Out:
# Date/Time           8784
# Temp_C               533
# Dew Point Temp_C     489
# Rel Hum_%             83
# Wind Speed_km/h       34
# Visibility_km         24
# Press_kPa            518
# Weather               50
# dtype: int64

# %%
data.count()
# Out:
# Date/Time           8784
# Temp_C              8783
# Dew Point Temp_C    8783
# Rel Hum_%           8783
# Wind Speed_km/h     8783
# Visibility_km       8783
# Press_kPa           8784
# Weather             8783
# dtype: int64

# %%
data.value_counts()
# Out:
# Date/Time       Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  Visibility_km  Press_kPa  Weather
# 1/1/2012 0:00   -1.8    -3.9              86.0       4.0              8.0            101.24     Fog             1
# 6/1/2012 13:00   19.5    4.0              36.0       17.0             48.3           101.29     Cloudy          1
# 5/9/2012 8:00    14.3    12.3             88.0       17.0             6.4            100.12     Fog             1
# 5/9/2012 9:00    14.0    12.3             89.0       9.0              4.0            100.10     Drizzle,Fog     1
# 6/1/2012 0:00    11.6    3.8              59.0       6.0              25.0           101.21     Clear           1
#                                                                                                                ..
# 12/8/2012 7:00   2.3     1.0              91.0       6.0              8.0            101.09     Fog             1
# ...

# %%
 data['Weather'].value_counts()
# Out:
# Weather
# Mainly Clear                               2106
# Mostly Cloudy                              2068
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8783 non-null   float64
#  2   Dew Point Temp_C  8783 non-null   float64
#  3   Rel Hum_%         8783 non-null   float64
#  4   Wind Speed_km/h   8783 non-null   float64
#  5   Visibility_km     8783 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8783 non-null   object
# dtypes: float64(6), object(2)
# memory usage: 549.1+ KB

# %% [markdown]
# **find all unique values of "wind speed"**

# %%
data['Wind Speed_km/h'].nunique()
# Out:
# 34

# %%
data['Wind Speed_km/h'].unique()
# Out:
# array([ 4.,  7.,  6.,  9., 15., 13., 20., 22., 19., 24., 30., 35., 39.,
#        32., 33., 26., 44., 43., 48., 37., nan, 28., 17., 11.,  0., 83.,
#        70., 57., 46., 41., 52., 50., 63., 54.,  2.])

# %% [markdown]
# **Find the number times when the "weather is exactly clear"**

# %%
data.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9       86.0              4.0
# 1  1/1/2012 1:00    -1.8              -3.7       87.0              4.0
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
data["Weather"].value_counts()   # value count option
# Out:
# Weather
# Mainly Clear                               2106
# Mostly Cloudy                              2068
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# ...

# %%
data[data.Weather=='Clear']  #by using filter method
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8       50.0             24.0
# 114     1/5/2012 18:00    -7.1             -14.4       56.0             11.0
# 115     1/5/2012 19:00    -9.2             -15.4       61.0              7.0
# 116     1/5/2012 20:00    -9.8             -15.7       62.0              9.0
# 117     1/5/2012 21:00    -9.0             -14.8       63.0             13.0
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8       89.0              4.0
# 8698  12/28/2012 10:00    -6.1              -8.6       82.0             19.0
# 8713   12/29/2012 1:00   -11.9             -13.6       87.0             11.0
# 8714   12/29/2012 2:00   -11.8             -13.1       90.0             13.0
# 8756  12/30/2012 20:00   -13.8             -16.5       80.0             24.0
#
#       Visibility_km  Press_kPa Weather
# ...

# %%
data.groupby('Weather').get_group('Clear')      #groupby syntax
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8       50.0             24.0
# 114     1/5/2012 18:00    -7.1             -14.4       56.0             11.0
# 115     1/5/2012 19:00    -9.2             -15.4       61.0              7.0
# 116     1/5/2012 20:00    -9.8             -15.7       62.0              9.0
# 117     1/5/2012 21:00    -9.0             -14.8       63.0             13.0
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8       89.0              4.0
# 8698  12/28/2012 10:00    -6.1              -8.6       82.0             19.0
# 8713   12/29/2012 1:00   -11.9             -13.6       87.0             11.0
# 8714   12/29/2012 2:00   -11.8             -13.1       90.0             13.0
# 8756  12/30/2012 20:00   -13.8             -16.5       80.0             24.0
#
#       Visibility_km  Press_kPa Weather
# ...

# %% [markdown]
# **Find the number times when the "wind speed is exactly 4km/h"**

# %%
#data.head(2)
data[data["Wind Speed_km/h"]==4]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9       86.0              4.0
# 1        1/1/2012 1:00    -1.8              -3.7       87.0              4.0
# 96       1/5/2012 0:00    -8.8             -11.7       79.0              4.0
# 101      1/5/2012 5:00    -7.0              -9.5       82.0              4.0
# 146      1/7/2012 2:00    -8.1             -11.1       79.0              4.0
# ...                ...     ...               ...        ...              ...
# 8768   12/31/2012 8:00    -8.6             -10.3       87.0              4.0
# 8769   12/31/2012 9:00    -8.1              -9.6       89.0              4.0
# 8770  12/31/2012 10:00    -7.4              -8.9       89.0              4.0
# 8772  12/31/2012 12:00    -5.8              -7.5       88.0              4.0
# 8773  12/31/2012 13:00    -4.6              -6.6       86.0              4.0
#
#       Visibility_km  Press_kPa       Weather
# ...

# %% [markdown]
# ****Find out all null values in Data****

# %%
data.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9       86.0              4.0
# 1  1/1/2012 1:00    -1.8              -3.7       87.0              4.0
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
data[data.isnull()].sum()
# Out:
# Date/Time             0
# Temp_C              0.0
# Dew Point Temp_C    0.0
# Rel Hum_%           0.0
# Wind Speed_km/h     0.0
# Visibility_km       0.0
# Press_kPa           0.0
# Weather               0
# dtype: object

# %%
data.notnull().sum()
# Out:
# Date/Time           8784
# Temp_C              8783
# Dew Point Temp_C    8783
# Rel Hum_%           8783
# Wind Speed_km/h     8783
# Visibility_km       8783
# Press_kPa           8784
# Weather             8783
# dtype: int64

# %% [markdown]
# ****Rename the "Weather" to "Weather Condition"****

# %%
data.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9       86.0              4.0
# 1  1/1/2012 1:00    -1.8              -3.7       87.0              4.0
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
data.rename(columns={'Weather':"Weather_Condition"},inplace=True)

# %%
data.rename(columns={'Date/Time':'Date&Time'},inplace=True)

# %%
data.head(2)
# Out:
#        Date&Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9       86.0              4.0
# 1  1/1/2012 1:00    -1.8              -3.7       87.0              4.0
#
#    Visibility_km  Press_kPa Weather_Condition
# 0            8.0     101.24               Fog
# 1            8.0     101.24               Fog

# %% [markdown]
# **What is the mean visibility**

# %%
data.Visibility_km.mean()
# Out:
# 27.66714106797222

# %%
data.describe()
# Out:
#             Temp_C  Dew Point Temp_C    Rel Hum_%  Wind Speed_km/h  \
# count  8783.000000       8783.000000  8783.000000      8783.000000
# mean      8.799351          2.555960    67.429694        14.944438
# std      11.688001         10.883513    16.918806         8.688653
# min     -23.300000        -28.500000    18.000000         0.000000
# 25%       0.100000         -5.900000    56.000000         9.000000
# 50%       9.300000          3.300000    68.000000        13.000000
# 75%      18.800000         11.800000    81.000000        20.000000
# max      33.000000         24.400000   100.000000        83.000000
#
#        Visibility_km    Press_kPa
# count    8783.000000  8784.000000
# mean       27.667141   101.051623
# std        12.620881     0.844005
# min         0.200000    97.520000
# 25%        24.100000   100.560000
# 50%        25.000000   101.070000
# 75%        25.000000   101.590000
# max        48.300000   103.650000

# %%
data[data['Weather_Condition'].str.contains('Snow', na=False)].head(50)
# Out:
#           Date&Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 41   1/2/2012 17:00    -2.1              -9.5       57.0             22.0
# 44   1/2/2012 20:00    -5.6             -13.4       54.0             24.0
# 45   1/2/2012 21:00    -5.8             -12.8       58.0             26.0
# 47   1/2/2012 23:00    -7.4             -14.1       59.0             17.0
# 48    1/3/2012 0:00    -9.0             -16.0       57.0             28.0
# 50    1/3/2012 2:00   -10.5             -15.8       65.0             22.0
# 51    1/3/2012 3:00   -11.3             -18.7       54.0             33.0
# 53    1/3/2012 5:00   -12.9             -19.1       60.0             22.0
# 54    1/3/2012 6:00   -13.3             -19.3       61.0             19.0
# 55    1/3/2012 7:00   -14.0             -19.5       63.0             19.0
# 84   1/4/2012 12:00   -13.7             -21.7       51.0             11.0
# 86   1/4/2012 14:00   -11.3             -19.0       53.0              7.0
# ...

# %% [markdown]
# **Find all instances when 'Wind Speed is above 24' and 'Visibility is 25'**

# %%
data.head(2)
# Out:
#        Date&Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9       86.0              4.0
# 1  1/1/2012 1:00    -1.8              -3.7       87.0              4.0
#
#    Visibility_km  Press_kPa Weather_Condition
# 0            8.0     101.24               Fog
# 1            8.0     101.24               Fog

# %%
data[(data['Wind Speed_km/h'] > 24 ) & (data.Visibility_km==25)]
# Out:
#              Date&Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 23      1/1/2012 23:00     5.3               2.0       79.0             30.0
# 24       1/2/2012 0:00     5.2               1.5       77.0             35.0
# 25       1/2/2012 1:00     4.6               0.0       72.0             39.0
# 26       1/2/2012 2:00     3.9              -0.9       71.0             32.0
# 27       1/2/2012 3:00     3.7              -1.5       69.0             33.0
# ...                ...     ...               ...        ...              ...
# 8705  12/28/2012 17:00    -8.6             -12.0       76.0             26.0
# 8753  12/30/2012 17:00   -12.1             -15.8       74.0             28.0
# 8755  12/30/2012 19:00   -13.4             -16.5       77.0             26.0
# 8759  12/30/2012 23:00   -12.1             -15.1       78.0             28.0
# 8760   12/31/2012 0:00   -11.1             -14.4       77.0             26.0
#
# ...

# %% [markdown]
# **Find all mean values of Weather condition indidual**

# %%
data.groupby("Weather_Condition").min()
# Out:
#                                                 Date&Time  Temp_C  \
# Weather_Condition
# Clear                                      1/11/2012 1:00   -23.3
# Cloudy                                     1/1/2012 17:00   -21.4
# Drizzle                                   1/23/2012 21:00     1.1
# Drizzle,Fog                               1/23/2012 20:00     0.0
# Drizzle,Ice Pellets,Fog                   12/17/2012 9:00     0.4
# Drizzle,Snow                             12/17/2012 15:00     0.9
# Drizzle,Snow,Fog                         12/18/2012 21:00     0.3
# Fog                                         1/1/2012 0:00   -16.0
# Freezing Drizzle                          1/13/2012 10:00    -9.0
# Freezing Drizzle,Fog                        1/1/2012 2:00    -6.4
# Freezing Drizzle,Haze                      2/1/2012 11:00    -5.8
# Freezing Drizzle,Snow                      1/13/2012 3:00    -8.3
# Freezing Fog                               1/22/2012 6:00   -19.0
# ...

# %%
data.groupby("Weather_Condition").max()
# Out:
#                                                 Date&Time  Temp_C  \
# Weather_Condition
# Clear                                       9/9/2012 5:00    32.8
# Cloudy                                     9/9/2012 23:00    30.5
# Drizzle                                    9/30/2012 3:00    18.8
# Drizzle,Fog                                9/30/2012 2:00    19.9
# Drizzle,Ice Pellets,Fog                   12/17/2012 9:00     0.4
# Drizzle,Snow                             12/19/2012 18:00     1.2
# Drizzle,Snow,Fog                          12/22/2012 3:00     1.1
# Fog                                        9/22/2012 0:00    20.8
# Freezing Drizzle                            2/1/2012 5:00    -2.3
# Freezing Drizzle,Fog                      12/10/2012 5:00    -0.3
# Freezing Drizzle,Haze                      2/1/2012 13:00    -5.0
# Freezing Drizzle,Snow                      3/2/2012 12:00    -3.3
# Freezing Fog                               3/17/2012 6:00    -0.1
# ...

# %%
data.groupby("Weather_Condition").get_group("Fog")
# Out:
#              Date&Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9       86.0              4.0
# 1        1/1/2012 1:00    -1.8              -3.7       87.0              4.0
# 4        1/1/2012 4:00    -1.5               NaN       88.0              7.0
# 5        1/1/2012 5:00    -1.4              -3.3       87.0              9.0
# 6        1/1/2012 6:00    -1.5              -3.1       89.0              7.0
# ...                ...     ...               ...        ...              ...
# 8716   12/29/2012 4:00   -16.0             -17.2       90.0              6.0
# 8717   12/29/2012 5:00   -14.8             -15.9       91.0              4.0
# 8718   12/29/2012 6:00   -13.8             -15.3       88.0              4.0
# 8719   12/29/2012 7:00   -14.8             -16.4       88.0              7.0
# 8722  12/29/2012 10:00   -12.0             -13.3       90.0              7.0
#
# ...

# %%
data[data['Weather_Condition'].str.contains('Fog', na=False)]
# Out:
#              Date&Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9       86.0              4.0
# 1        1/1/2012 1:00    -1.8              -3.7       87.0              4.0
# 2        1/1/2012 2:00     NaN              -3.4       89.0              7.0
# 3        1/1/2012 3:00    -1.5              -3.2       88.0              6.0
# 4        1/1/2012 4:00    -1.5               NaN       88.0              7.0
# ...                ...     ...               ...        ...              ...
# 8739   12/30/2012 3:00    -9.1             -10.4       90.0             11.0
# 8740   12/30/2012 4:00    -9.3             -10.6       90.0             13.0
# 8741   12/30/2012 5:00    -9.1             -10.4       90.0             11.0
# 8742   12/30/2012 6:00    -9.3             -10.8       89.0             17.0
# 8770  12/31/2012 10:00    -7.4              -8.9       89.0              4.0
#
# ...

# %%
data[data["Weather_Condition"]=='Fog']
# Out:
#              Date&Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9       86.0              4.0
# 1        1/1/2012 1:00    -1.8              -3.7       87.0              4.0
# 4        1/1/2012 4:00    -1.5               NaN       88.0              7.0
# 5        1/1/2012 5:00    -1.4              -3.3       87.0              9.0
# 6        1/1/2012 6:00    -1.5              -3.1       89.0              7.0
# ...                ...     ...               ...        ...              ...
# 8716   12/29/2012 4:00   -16.0             -17.2       90.0              6.0
# 8717   12/29/2012 5:00   -14.8             -15.9       91.0              4.0
# 8718   12/29/2012 6:00   -13.8             -15.3       88.0              4.0
# 8719   12/29/2012 7:00   -14.8             -16.4       88.0              7.0
# 8722  12/29/2012 10:00   -12.0             -13.3       90.0              7.0
#
# ...

# %% [markdown]
# **Thank You**

# %% [markdown]
# ##**Thank You**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# **Set a Seaborn theme for better aesthetics**

# %%
sns.set_theme(style="whitegrid")

# %% [markdown]
# **Plot 1: Weather Condition Frequency**

# %%
plt.figure(figsize=(14, 6))
sns.countplot(y='Weather_Condition', data=data, order=data['Weather_Condition'].value_counts().index)
plt.title("Frequency of Different Weather Conditions")
plt.xlabel("Count")
plt.ylabel("Weather Condition")
plt.show()

# %% [markdown]
# **Plot 2: Temperature Distribution by Weather Condition (Top 10)**

# %%
plt.figure(figsize=(14, 6))
sns.boxplot(x='Weather_Condition', y='Temp_C', data=data, order=data['Weather_Condition'].value_counts().index[:10])
plt.title("Temperature Distribution by Weather Condition (Top 10)")
plt.xlabel("Weather Condition")
plt.ylabel("Temperature (°C)")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Plot 3: Scatter Plot of Humidity vs. Temperature**

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Temp_C', y='Rel Hum_%', data=data, hue='Weather_Condition', palette='cool', legend=False)
plt.title("Humidity vs. Temperature Scatter Plot")
plt.xlabel("Temperature (°C)")
plt.ylabel("Relative Humidity (%)")
plt.show()

# %% [markdown]
# **Plot 4: Visibility under Different Weather Conditions (Top 10)**

# %%
plt.figure(figsize=(14, 6))
sns.boxplot(x='Weather_Condition', y='Visibility_km', data=data, order=data['Weather_Condition'].value_counts().index[:10])
plt.title("Visibility Distribution by Weather Condition (Top 10)")
plt.xlabel("Weather Condition")
plt.ylabel("Visibility (km)")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Plot 5: Temperature Trends Over Time**

# %%
plt.figure(figsize=(14, 6))
sns.lineplot(x='Date&Time', y='Temp_C', data=data)
plt.title("Temperature Trends Over Time")
plt.xlabel("Date & Time")
plt.ylabel("Temperature (°C)")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Plot 6: Wind Speed Distribution**

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data['Wind Speed_km/h'], bins=20, kde=True)
plt.title("Distribution of Wind Speed")
plt.xlabel("Wind Speed (km/h)")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# **Plot 7: Humidity vs. Visibility**

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Rel Hum_%', y='Visibility_km', data=data, hue='Weather_Condition', palette='viridis', legend=False)
plt.title("Humidity vs. Visibility")
plt.xlabel("Relative Humidity (%)")
plt.ylabel("Visibility (km)")
plt.show()

# %% [markdown]
# **Plot 8: Correlation Heatmap**

# %%
# Select only numeric columns for correlation calculation
numeric_data = data.select_dtypes(include=['float64', 'int64'])

# Plot the correlation heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(numeric_data.corr(), annot=True, cmap='coolwarm', linewidths=0.5)
plt.title("Correlation Heatmap of Weather Variables")
plt.show()

# %% [markdown]
# **Plot 9: Pair Plot of Key Features**

# %%
sns.pairplot(data[['Temp_C', 'Rel Hum_%', 'Visibility_km', 'Wind Speed_km/h']], diag_kind='kde')
plt.suptitle("Pair Plot of Key Weather Features", y=1.02)
plt.show()
